# %%
import os
import wget

# data from https://www.sciencedirect.com/science/article/pii/S2352340920303048

# Download the zipped dataset
url = 'https://md-datasets-cache-zipfiles-prod.s3.eu-west-1.amazonaws.com/yshdbyj6zy-1.zip'
zip_name = "data.zip"
wget.download(url, zip_name)

# Unzip it and standardize the .csv filename
import zipfile
with zipfile.ZipFile(zip_name,"r") as zip_ref:
    zip_ref.filelist[0].filename = 'data_raw.csv'
    zip_ref.extract(zip_ref.filelist[0])

os.remove(zip_name)

# %%
import pandas as pd

# %%
df=pd.read_csv("data_raw.csv")

# %%
df.head()
# Out:
#    id              date  total_agr_land  workforce  trees  arable_land  ley  \
# 0   1  13.03.2019 10:59          4925.0    1.95406     79         3871  107
# 1   2  13.03.2019 11:08          2176.0    6.61310     12         1671    0
# 2   3  13.03.2019 11:37          2251.0    1.39384     31         1507  279
# 3   4  13.03.2019 13:54          2389.0    1.99523      3         1969   71
# 4   5  13.03.2019 14:18          3205.0    3.09942     39         1911  675
#
#    perm_grass  perm_crops  prot_cult  ...  network  GHG_goal  env_goal  \
# 0         793         140          0  ...        2         1         5
# 1          98         338        119  ...        1         3         4
# 2         380          81          0  ...        3         1         4
# 3         322           0          0  ...        1         2         5
# 4         461         117          0  ...        3         1         6
#
#    biodiv_goal  acknow_goal  yield_goal  income_goal  info_gew  info_resul  \
# 0            6            4           3            2         2           2
# 1            2            1           6            5         2           2
# 2            2            3           6            5         1           1
# 3            4            1           3            6         2           1
# 4            3            2           5            4         2           2
#
#    interviewtime
# 0         999.53
# 1         901.99
# 2        1832.99
# 3        2001.28
# 4        1809.30
#
# [5 rows x 227 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Columns: 227 entries, id to interviewtime
# dtypes: float64(139), int64(85), object(3)
# memory usage: 186.3+ KB

# %%
df.describe()
# Out:
#                id  total_agr_land   workforce       trees   arable_land  \
# count  105.000000      102.000000  102.000000  105.000000    105.000000
# mean    53.000000     2946.029412    2.977482   43.657143   1871.761905
# std     30.454885     2167.942313    6.527054   37.532762   1822.617652
# min      1.000000       96.000000    0.137280    0.000000      0.000000
# 25%     27.000000     1848.250000    0.953778   13.000000    965.000000
# 50%     53.000000     2587.000000    1.810360   32.000000   1565.000000
# 75%     79.000000     3810.250000    3.072593   65.000000   2410.000000
# max    105.000000    18713.000000   63.732270  159.000000  15779.000000
#
#                ley   perm_grass   perm_crops   prot_cult  add_agr_land  ...  \
# count   105.000000   105.000000   105.000000  105.000000    105.000000  ...
# mean    318.742857   502.247619   128.190476    9.666667     13.980952  ...
# std     383.263066   433.437086   409.818865   63.588471     25.386997  ...
# min       0.000000     0.000000     0.000000    0.000000      0.000000  ...
# 25%       0.000000   203.000000     0.000000    0.000000      0.000000  ...
# 50%     180.000000   425.000000     7.000000    0.000000      3.000000  ...
# 75%     505.000000   694.000000   118.000000    0.000000     17.000000  ...
# max    1663.000000  2700.000000  3730.000000  616.000000    122.000000  ...
#
#           network    GHG_goal   env_goal  biodiv_goal  acknow_goal  \
# count  105.000000  105.000000  105.00000   105.000000   105.000000
# mean     4.914286    2.828571    4.72381     3.980952     2.066667
# std      3.314056    1.369005    1.28224     1.493453     1.648231
# min      1.000000    1.000000    1.00000     1.000000     1.000000
# 25%      2.000000    2.000000    4.00000     3.000000     1.000000
# 50%      4.000000    3.000000    5.00000     4.000000     1.000000
# 75%      8.000000    4.000000    6.00000     5.000000     3.000000
# max     10.000000    6.000000    6.00000     6.000000     6.000000
#
#        yield_goal  income_goal    info_gew  info_resul  interviewtime
# count  105.000000   105.000000  105.000000  105.000000     105.000000
# mean     3.076190     4.323810    1.542857    1.342857    2372.323619
# std      1.465601     1.383246    0.500549    0.476941    1651.122671
# min      1.000000     1.000000    1.000000    1.000000     822.040000
# 25%      2.000000     3.000000    1.000000    1.000000    1357.520000
# 50%      3.000000     4.000000    2.000000    1.000000    1883.430000
# 75%      4.000000     6.000000    2.000000    2.000000    2713.020000
# max      6.000000     6.000000    2.000000    2.000000   10297.400000
#
# [8 rows x 224 columns]

# %%
len(df.columns)
# Out:
# 227

# %%
all_features = df.columns

# Let's drop some features
names = [feat for feat in all_features if "net_name" in feat]

# %%
names = [feat for feat in all_features if "net_name" in feat] # excluded for privacy reasons
useless = ["info_gew","info_resul","interviewtime","id","date"] # features that we expect are uninformative
drop_list = names + useless

# %%
practice_list = ["legum","conc","add","lact","breed","covman","comp","drag","cov","plow","solar","biog","ecodr"]
for feat in all_features:
    if any(x in feat for x in practice_list):
        drop_list.append(feat)

# %%
df = df.drop(columns=drop_list)

# %%
df.head()
# Out:
#    total_agr_land  workforce  trees  arable_land  ley  perm_grass  perm_crops  \
# 0          4925.0    1.95406     79         3871  107         793         140
# 1          2176.0    6.61310     12         1671    0          98         338
# 2          2251.0    1.39384     31         1507  279         380          81
# 3          2389.0    1.99523      3         1969   71         322           0
# 4          3205.0    3.09942     39         1911  675         461         117
#
#    prot_cult  oth_land  qual_landscape  ...  lott_1  lott_2  lott_3  network  \
# 0          0       165               0  ...       8      12       3        2
# 1        119        93               0  ...       1       2       3        1
# 2          0       512               0  ...       3       9       8        3
# 3          0       350               0  ...       6       9       4        1
# 4          0       112               0  ...       7       7       3        3
#
#    GHG_goal  env_goal  biodiv_goal  acknow_goal  yield_goal  income_goal
# 0         1         5            6            4           3            2
# 1         3         4            2            1           6            5
# 2         1         4            2            3           6            5
# 3         2         5            4            1           3            6
# 4         1         6            3            2           5            4
#
# [5 rows x 82 columns]

# %%
non_numeric = list(df.select_dtypes(include=['O']).columns)

# %%
non_numeric
# Out:
# ['farmtype', 'region']

# %%
df[["farmtype","region"]]
# Out:
#               farmtype           region
# 0            Livestock  Kohlfirst/Rhein
# 1       Arable farming  Kohlfirst/Rhein
# 2            Livestock  Kohlfirst/Rhein
# 3            Livestock        Flaachtal
# 4            Livestock  Kohlfirst/Rhein
# ..                 ...              ...
# 100          Livestock          Thurtal
# 101  Specialized crops        Flaachtal
# 102          Livestock        Flaachtal
# 103          Livestock        Flaachtal
# 104          Livestock        Flaachtal
#
# [105 rows x 2 columns]

# %%
# Out:
# [ 0  1  0  0  0  2  1 -1  0  0  0  0  2  0  0  2  0  1  0  0  3  0  3  3
#   1  0  1  0  0  0  0  2  3  1  0  0  0 -1  0  0  1  0  1  2  0  0  0  0
#   1  2  1  2  1  0  1  0  0 -1  0  0  0  0  3  0  0  0  1  1  1  0  0  1
#   3  0  0  0  0  0  0  0  0  3  1  0  2  2  0  1  0  0  1  1  3  1  1  0
#   0  1  0  0  0  3  0  0  0] Index(['Livestock', 'Arable farming', 'Others', 'Specialized crops'], dtype='object')
# [0 0 0 1 0 2 0 3 4 1 4 1 0 2 2 0 2 1 1 4 4 1 0 1 1 0 1 2 4 4 1 1 3 4 4 4 2
#  3 2 0 1 4 4 4 0 1 1 0 0 1 1 2 0 2 1 2 0 3 2 4 1 1 0 0 2 2 1 1 1 2 3 4 3 1
#  2 1 1 4 1 1 0 1 1 0 1 0 2 1 2 2 0 1 3 0 4 0 2 0 2 2 2 1 1 1 1] Index(['Kohlfirst/Rhein', 'Flaachtal', 'Thurtal', 'Andere Gemeinde',
#        'Stammertal'],
#       dtype='object')

# %%
non_numeric = list(df.select_dtypes(include=['O']).columns)
for col in non_numeric:
    code,uniques=pd.factorize(df[col])
    df[col] = code

# %%
df[["farmtype"]]
# Out:
#      farmtype
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
# ..        ...
# 100         0
# 101         3
# 102         0
# 103         0
# 104         0
#
# [105 rows x 1 columns]

# %%
df.to_csv("data_processed.csv")

# %%
data=pd.read_csv("data_processed.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 83 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          105 non-null    int64
#  1   total_agr_land      102 non-null    float64
#  2   workforce           102 non-null    float64
#  3   trees               105 non-null    int64
#  4   arable_land         105 non-null    int64
#  5   ley                 105 non-null    int64
#  6   perm_grass          105 non-null    int64
#  7   perm_crops          105 non-null    int64
#  8   prot_cult           105 non-null    int64
#  9   oth_land            105 non-null    int64
#  10  qual_landscape      105 non-null    int64
#  11  spec_crops          105 non-null    int64
#  12  grapes              105 non-null    int64
#  13  vegetables          105 non-null    int64
#  14  fruits              105 non-null    int64
#  15  oth_spec_crops      105 non-null    int64
#  16  animal_unit         105 non-null    float64
#  17  cattle_animal_unit  105 non-null    float64
#  18  dairy_cows          105 non-null    float64
#  19  suckler_cows        105 non-null    float64
#  20  hor_shee_goa        105 non-null    float64
#  21  pigs_poultry        105 non-null    float64
#  22  pigs                105 non-null    float64
#  23  poultry             105 non-null    float64
#  24  eco_proof           102 non-null    float64
#  25  organic             101 non-null    float64
#  26  farmtype            105 non-null    int64
#  27  region              105 non-null    int64
#  28  age                 84 non-null     float64
#  29  educ                105 non-null    int64
#  30  cons_general        105 non-null    int64
#  31  percep_hail         105 non-null    int64
#  32  percep_drought      105 non-null    int64
#  33  percep_frost        105 non-null    int64
#  34  percep_heavyrain    105 non-null    int64
#  35  percep_longrain     105 non-null    int64
#  36  percep_heat         105 non-null    int64
#  37  cons_farm           105 non-null    int64
#  38  self_reduc          105 non-null    int64
#  39  self_act            105 non-null    int64
#  40  self_cap            105 non-null    int64
#  41  self_conf           105 non-null    int64
#  42  self_not            105 non-null    int64
#  43  plough              105 non-null    int64
#  44  plough_eff          95 non-null     float64
#  45  plough_imag         72 non-null     float64
#  46  activ_dairy         105 non-null    int64
#  47  activ_cattle        105 non-null    int64
#  48  activ_pig           105 non-null    int64
#  49  activ_poultry       105 non-null    int64
#  50  activ_arab          105 non-null    int64
#  51  activ_special       105 non-null    int64
#  52  activ_nonag         105 non-null    int64
#  53  attain_ghg          105 non-null    int64
#  54  attain_yield        105 non-null    int64
#  55  attain_biodiv       105 non-null    int64
#  56  attain_soil         105 non-null    int64
#  57  attain_incom        105 non-null    int64
#  58  attain_acknow       105 non-null    int64
#  59  innov_pion          105 non-null    int64
#  60  innov_early         105 non-null    int64
#  61  innov_thorou        105 non-null    int64
#  62  innov_others        105 non-null    int64
#  63  innov_trad          105 non-null    int64
#  64  satisf_ldw          105 non-null    int64
#  65  thresh_ldw          105 non-null    int64
#  66  satisf_total        105 non-null    int64
#  67  thresh_total        105 non-null    int64
#  68  share               105 non-null    int64
#  69  others_opinions     105 non-null    int64
#  70  soc_impr            105 non-null    int64
#  71  soc_inc             105 non-null    int64
#  72  soc_env             105 non-null    int64
#  73  lott_1              105 non-null    int64
#  74  lott_2              105 non-null    int64
#  75  lott_3              105 non-null    int64
#  76  network             105 non-null    int64
#  77  GHG_goal            105 non-null    int64
#  78  env_goal            105 non-null    int64
#  79  biodiv_goal         105 non-null    int64
#  80  acknow_goal         105 non-null    int64
#  81  yield_goal          105 non-null    int64
#  82  income_goal         105 non-null    int64
# dtypes: float64(15), int64(68)
# memory usage: 68.2 KB

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.model_selection import train_test_split
import json
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

df = pd.read_csv("data_processed.csv")

#### Get features ready to model! 
y = df.pop("cons_general").to_numpy()
y[y< 4] = 0
y[y>= 4] = 1

X = df.to_numpy()
X = preprocessing.scale(X) # Is standard
# Impute NaNs

imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(X)
X = imp.transform(X)


# Linear model
clf = LogisticRegression()
yhat = cross_val_predict(clf, X, y, cv=5)

acc = np.mean(yhat==y)
tn, fp, fn, tp = confusion_matrix(y, yhat).ravel()
specificity = tn / (tn+fp)
sensitivity = tp / (tp + fn)

# Now print to file
with open("metrics.json", 'w') as outfile:
        json.dump({ "accuracy": acc, "specificity": specificity, "sensitivity":sensitivity}, outfile)

# Let's visualize within several slices of the dataset
score = yhat == y
score_int = [int(s) for s in score]
df['pred_accuracy'] = score_int

# Bar plot by region

sns.set_color_codes("dark")
ax = sns.barplot(x="region", y="pred_accuracy", data=df, palette = "Greens_d")
ax.set(xlabel="Region", ylabel = "Model accuracy")
plt.savefig("by_region.png",dpi=80)
